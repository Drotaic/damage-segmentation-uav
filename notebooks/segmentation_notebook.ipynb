# %% [markdown]
# # 🧱 Damage Segmentation UAV Training
#
# This notebook uses U-Net or DeepLabV3+ to segment building damage in aerial images.

# %%
# Install required packages
# !pip install tensorflow opencv-python matplotlib

# %%
# Imports
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os

# %% [markdown]
# This is a starter notebook.
# - Load images and masks
# - Preprocess to size 256x256
# - Build U-Net model
# - Train and visualize predictions
